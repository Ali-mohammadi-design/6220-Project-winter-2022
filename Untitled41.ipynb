# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-mohammadi-design/6220-Project-winter-2022/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hello word
# Out:
#   File "<ipython-input-1-6c0dbe625aa9>", line 1
#     Hello word
#           ^
# SyntaxError: invalid syntax
